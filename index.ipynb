# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
import pandas as pd 
import sqlite3
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

cur.execute('''SELECT e.firstName, e.lastName, o.city, o.state FROM employees e
                LEFT JOIN offices o ON (o.officeCode = e.officeCode)
                ORDER BY e.firstName, e.lastName''')

df = pd.DataFrame(cur.fetchall())
df.columns = (i[0] for i in cur.description)
df
# Out:
#    firstName   lastName           city       state
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
# cur.execute('''
#                 SELECT c.customerName, o.orderNumber, o.orderDate, o.status
#                 FROM customers c JOIN orders o ON (c.customerNumber = o.customerNumber)
#                 ORDER BY c.customerName
#             ''')

cur.execute('''
                SELECT c.customerName, p.customerNumber, p.amount, p.paymentDate, p.checkNumber FROM payments p 
                         JOIN customers c 
                         using(customerNumber);
            ''')

df = pd.DataFrame(cur.fetchall())
df.columns = (i[0] for i in cur.description)
df
# Out:
#                        customerName customerNumber     amount paymentDate  \
# 0                 Atelier graphique            103    6066.78  2004-10-19
# 1                 Atelier graphique            103   14571.44  2003-06-05
# 2                 Atelier graphique            103    1676.14  2004-12-18
# 3                Signal Gift Stores            112   14191.12  2004-12-17
# 4                Signal Gift Stores            112   32641.98  2003-06-06
# 5                Signal Gift Stores            112   33347.88  2004-08-20
# 6        Australian Collectors, Co.            114   45864.03  2003-05-20
# 7        Australian Collectors, Co.            114   82261.22  2004-12-15
# 8        Australian Collectors, Co.            114    7565.08  2003-05-31
# 9        Australian Collectors, Co.            114   44894.74  2004-03-10
# 10                La Rochelle Gifts            119   19501.82  2004-11-14
# 11                La Rochelle Gifts            119   47924.19  2004-08-08
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cur.execute('''
                SELECT o.orderNumber, od.quantityOrdered, od.priceEach, od.orderLineNumber FROM orders o
                JOIN orderdetails od ON (od.orderNumber = o.orderNumber)
            ''')

df = pd.DataFrame(cur.fetchall())
df.columns = (i[0] for i in cur.description)
df
# Out:
#      orderNumber quantityOrdered priceEach orderLineNumber
# 0          10100              22     75.46               4
# 1          10100              30    136.00               3
# 2          10100              49     35.29               1
# 3          10100              50     55.09               2
# 4          10101              25    108.06               4
# 5          10101              26    167.06               1
# 6          10101              45     32.53               3
# 7          10101              46     44.35               2
# 8          10102              39     95.55               2
# 9          10102              41     43.13               1
# 10         10103              22     58.34               2
# 11         10103              25     86.92              13
# 12         10103              25     88.62              15
# 13         10103              26    214.30              11
# 14         10103              27    121.64               8
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
# Your code here
cur.execute('''
                SELECT o.orderNumber, od.quantityOrdered, od.priceEach, od.orderLineNumber, p.productName, p.productDescription FROM orders o
                JOIN orderdetails od ON (od.orderNumber = o.orderNumber)
                JOIN products p ON (od.productCode = p.productCode)
            ''')

df = pd.DataFrame(cur.fetchall())
df.columns = (i[0] for i in cur.description)
df
# Out:
#      orderNumber quantityOrdered priceEach orderLineNumber  \
# 0          10100              30    136.00               3
# 1          10100              50     55.09               2
# 2          10100              22     75.46               4
# 3          10100              49     35.29               1
# 4          10101              25    108.06               4
# 5          10101              26    167.06               1
# 6          10101              45     32.53               3
# 7          10101              46     44.35               2
# 8          10102              39     95.55               2
# 9          10102              41     43.13               1
# 10         10103              26    214.30              11
# 11         10103              42    119.67               4
# 12         10103              27    121.64               8
# 13         10103              35     94.50              10
# 14         10103              22     58.34               2
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
